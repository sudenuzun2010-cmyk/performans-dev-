# %% [markdown]
# <a href="https://colab.research.google.com/github/sudenuzun2010-cmyk/performans-dev-/blob/main/scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ad_soyad = "suden uzun"
print(ad_soyad)
# Out:
# suden uzun
