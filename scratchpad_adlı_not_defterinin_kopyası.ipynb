# %% [markdown]
# <a href="https://colab.research.google.com/github/sudenuzun2010-cmyk/performans-dev-/blob/main/scratchpad_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello

# %%
yıl = 2023

if (yıl % 4 == 0 and year % 100 != 0) or (yıl % 400 == 0):
    print(f"{yıl} bir artık yıldır.")
else:
    print(f"{yıl} bir artık yıl değildir.")
#ssoru11
# Out:
# 2023 bir artık yıl değildir.

# %%
vize = float(input("Vize notunuzu girin: "))
final = float(input("Final notunuzu girin: "))

ortalama = (vize + final) / 2

print(f"Ortalamanız: {ortalama}")
#soru31
# Out:
# Vize notunuzu girin: 13
# Final notunuzu girin: 5
# Ortalamanız: 9.0

# %%
my_list = [50, 60, 90]
print(f"lıste1: {my_list}")

my_list.reverse()
print(f"liste2: {my_list}")
# Out:
# lıste1: [50, 60, 90]
# liste2: [90, 60, 50]
